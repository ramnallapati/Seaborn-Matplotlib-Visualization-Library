# %% [markdown]
# <h3 style="color:blue;text-align:center">Stacked Bar Chart</h3>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.random.seed(2)

years = np.random.choice
